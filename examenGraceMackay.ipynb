# %% [markdown]
# ## Examen Manejo de Datos
#
# # Mortalidad Materna
# por Grace Mackay

# %% [markdown]
# ### Importar datos de la base de datos:
# mortalidad.csv
#
# analisis inicial del archivo

# %%
#importar librerias necesarias
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#leo mis datos del archivo mortalidad
mortalidad=pd.read_csv('mortalidad.csv')

#metodo rudo
print(mortalidad)
# Out:
#        Año de nacimiento  Mes de nacimiento Descripción del mes de nacimiento  \
# 0                   1972                  6                             JUNIO
# 1                   1967                  2                           FEBRERO
# 2                   1973                  6                             JUNIO
# 3                   1966                  1                             ENERO
# 4                   1975                  0                   NO ESPECIFICADO
# 5                   1975                  0                   NO ESPECIFICADO
# 6                   1985                  0                   NO ESPECIFICADO
# 7                   1978                  7                             JULIO
# 8                   1958                  9                        SEPTIEMBRE
# 9                   1970                  5                              MAYO
# 10                  1972                  4                             ABRIL
# ...

# %%
# listar con DataFrame
pd.DataFrame(mortalidad)
# Out:
#        Año de nacimiento  Mes de nacimiento Descripción del mes de nacimiento  \
# 0                   1972                  6                             JUNIO
# 1                   1967                  2                           FEBRERO
# 2                   1973                  6                             JUNIO
# 3                   1966                  1                             ENERO
# 4                   1975                  0                   NO ESPECIFICADO
# 5                   1975                  0                   NO ESPECIFICADO
# 6                   1985                  0                   NO ESPECIFICADO
# 7                   1978                  7                             JULIO
# 8                   1958                  9                        SEPTIEMBRE
# 9                   1970                  5                              MAYO
# 10                  1972                  4                             ABRIL
# ...

# %%
#ver encabezados
# Encabezados
mortalidad.head(3)
# Out:
#    Año de nacimiento  Mes de nacimiento Descripción del mes de nacimiento  \
# 0               1972                  6                             JUNIO
# 1               1967                  2                           FEBRERO
# 2               1973                  6                             JUNIO
#
#    Día de nacimiento  Genero Clave de la edad  Edad cumplida  Estado conyugal  \
# 0                 25       2                A             29                5
# 1                  1       2                A             35                5
# 2                 21       2                A             29                5
#
#   Descripción del estado conyugal  Entidad de residencia  \
# 0                          CASADO                     31
# 1                          CASADO                     31
# 2                          CASADO                     31
#
#                          ...                         Mes de registro  \
# ...

# %%
# Motivos de mortalidad
# para mi gusto faltan datos en la recopilación de datos

mortalidad["Descrición de la razón de mortalidad materna"].unique()
# Out:
# array(['Muertes Maternas para la razón de Mortalidad Materna',
#        'Muertes Maternas excluidas para la razón de Mortalidad Materna'],
#       dtype=object)

# %%
mortalidad["Descripción del estado conyugal"].unique()
# Out:
# array(['CASADO', 'SE IGNORA', 'SEPARADO', 'DIVORCIADO', 'UNION LIBRE',
#        'SOLTERO', 'VIUDO', 'NO APLICA A MENORES DE 12 AÑOS'], dtype=object)

# %%
# Generación de pandita ( Tomo una sola columna)
estado_civil=mortalidad['Estado conyugal']

# %%
#mortalidad.describe()  estadisticos basicos
mortalidad.describe()
# que en este momento debo definir una base de datos con solo los campos que quiero describir.
# asi tiene muchos campos que no creo se les aplican la estadistica básica.
# Out:
#        Año de nacimiento  Mes de nacimiento  Día de nacimiento   Genero  \
# count       17232.000000       17232.000000       17232.000000  17232.0
# mean         1971.559424           3.758008           9.903726      2.0
# std           128.025187           3.756571          10.157461      0.0
# min             0.000000           0.000000           0.000000      2.0
# 25%          1974.000000           0.000000           0.000000      2.0
# 50%          1980.000000           3.000000           7.000000      2.0
# 75%          1986.000000           7.000000          19.000000      2.0
# max          2002.000000          12.000000          31.000000      2.0
#
#        Edad cumplida  Estado conyugal  Entidad de residencia  \
# count   17232.000000     17232.000000           17232.000000
# mean       29.765727         3.918001              16.293350
# std        36.916010         1.454535               7.844138
# min        11.000000         0.000000               0.000000
# ...

# %%
# crear una base para trabajar

mortalidad2=mortalidad.drop(['Mes de nacimiento','Día de nacimiento','Genero','Entidad de registro','Descrición de la entidad de registro', 'Municipio de registro','Descrición del municipio de registro','Año de registro','Mes de registro','Descripción del mes de registro',
                 'Día de registro','Año de la certificación','Mes de la certificación','Descripció del mes de la certificación','Día de la certificación'],axis=1)
# print(mortalidad2)
#pd.DataFrame(mortalidad2)
mortalidad2.head(2)
# Out:
#    Año de nacimiento Descripción del mes de nacimiento Clave de la edad  \
# 0               1972                             JUNIO                A
# 1               1967                           FEBRERO                A
#
#    Edad cumplida  Estado conyugal Descripción del estado conyugal  \
# 0             29                5                          CASADO
# 1             35                5                          CASADO
#
#    Entidad de residencia Descripción de entidad de residencia  \
# 0                     31                              Yucatán
# 1                     31                              Yucatán
#
#    Municipio de residencia Descripción del municipio de residencia  \
# 0                      102                          102 VALLADOLID
# 1                       96                             096 TIZIMIN
#
#                          ...                          Minutos de la defunción  \
# ...

# %%
ML=mortalidad2.set_index('Descripción de entidad de residencia')
ML.head()
# Out:
#                                       Mes de nacimiento  \
# Descripción de entidad de residencia
# Yucatán                                               6
# Yucatán                                               2
# Yucatán                                               6
# Yucatán                                               1
# Distrito Federal                                      0
#
#                                      Descripción del mes de nacimiento  \
# Descripción de entidad de residencia
# Yucatán                                                          JUNIO
# Yucatán                                                        FEBRERO
# Yucatán                                                          JUNIO
# Yucatán                                                          ENERO
# Distrito Federal                                       NO ESPECIFICADO
#
#                                       Día de nacimiento  Genero  \
# Descripción de entidad de residencia
# ...

# %%
CM=mortalidad2.set_index('Descrición de la causa CIE')
CM.head()
# Out:
#                                                     Año de nacimiento  \
# Descrición de la causa CIE
# O994  Enfermedades del sistema circulatorio que...               1972
# O141  Preeclampsia severa                                        1967
# O159  Eclampsia, en período no especificado                      1973
# O159  Eclampsia, en período no especificado                      1966
# O266  Trastornos del hígado en el embarazo, el ...               1975
#
#                                                    Descripción del mes de nacimiento  \
# Descrición de la causa CIE
# O994  Enfermedades del sistema circulatorio que...                             JUNIO
# O141  Preeclampsia severa                                                    FEBRERO
# O159  Eclampsia, en período no especificado                                    JUNIO
# O159  Eclampsia, en período no especificado                                    ENERO
# ...

# %% [markdown]
# ## Proyecto Analisis de defunciones de mujeres en México
#
# ### con el presente documento, contestar algunas preguntas:
#     ### Relación de muertes con tamaño de la localidad en que radican
#     ### Relación de muertes con atencion medica
#     ### relación de muertes con edad
